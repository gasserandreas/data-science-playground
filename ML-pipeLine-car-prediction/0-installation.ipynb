# %% [markdown]
# # 【Data Science Project】 Building a Machine Learning Pipeline for a Predictive Car Price Model with PySpark
#
# Simple notebook to install and provide tools used for other notebooks

# %% [markdown]
# To install:
#
# - `install necessary tools`
# - `sudo conda install openjdk`
# - `sudo conda install pyspark`
# - `sudo conda install -c conda-forge findspark`
